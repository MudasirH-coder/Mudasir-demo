# %% [markdown]
# <a href="https://colab.research.google.com/github/MudasirH-coder/Mudasir-demo/blob/main/Ecommerce.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ecommerce (Malti-Gauri) Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
orders = pd.read_csv('/customers.csv')
orders.head()
# Out:
#    customer_id first_name last_name                    email       phone  \
# 0            1        Sai    Sharma     ssharma251@yahoo.com  9117550026
# 1            2      Aarav  Kulkarni  akulkarni715@example.in  9319300868
# 2            3     Saanvi    Khanna     skhanna722@gmail.com  9022021263
# 3            4     Ishaan    Kapoor    ikapoor168@example.in  9396568720
# 4            5      Kiara      Nair     knair147@outlook.com  9175745391
#
#         city        state  pincode  created_at
# 0     Jaipur    Rajasthan   477442  2024-06-09
# 1       Pune  Maharashtra   859358  2023-09-26
# 2    Kolkata  West Bengal   636760  2023-10-13
# 3  Ahmedabad      Gujarat   640957  2022-08-06
# 4      Patna        Bihar   800167  2023-03-09

# %% [markdown]
# How many total orders have been placed ?

# %%
orders = pd.read_csv('/orders.csv')
orders.head()
# Out:
#    order_id  customer_id       order_datetime payment_method order_status  \
# 0         1          326  2025-03-09 14:44:00            COD    DELIVERED
# 1         2          214  2024-06-15 04:32:00            UPI    DELIVERED
# 2         3           67  2025-06-09 16:07:00     Debit Card    DELIVERED
# 3         4           17  2024-06-09 17:23:00            COD    CONFIRMED
# 4         5          210  2024-04-22 03:23:00    Credit Card       PLACED
#
#   shipping_city shipping_state  shipping_pincode  order_total
# 0         Delhi          Delhi            848534     34677.49
# 1     Bengaluru      Karnataka            364268      2309.37
# 2         Patna          Bihar            690607      6877.02
# 3         Delhi          Delhi            463589      1529.48
# 4         Kochi         Kerala            753052      5395.26

# %% [markdown]
# Analysing the total number of the id's

# %%
total_orders = orders['order_id'].nunique()
print(total_orders)
# Out:
# 800

# %% [markdown]
# Q; WHAT IS THE TOTAL REVENUE GENERATED BY THE PLATFORM

# %%
orders.head(3)
# Out:
#    order_id  customer_id       order_datetime payment_method order_status  \
# 0         1          326  2025-03-09 14:44:00            COD    DELIVERED
# 1         2          214  2024-06-15 04:32:00            UPI    DELIVERED
# 2         3           67  2025-06-09 16:07:00     Debit Card    DELIVERED
#
#   shipping_city shipping_state  shipping_pincode  order_total
# 0         Delhi          Delhi            848534     34677.49
# 1     Bengaluru      Karnataka            364268      2309.37
# 2         Patna          Bihar            690607      6877.02

# %% [markdown]
# **bold text**Ecommerce company generated a total_revenue (orders_total)

# %%
total_revenue=orders["order_total"].sum().round(2)
print(total_revenue)
# Out:
# 14371866.37

# %% [markdown]
# What is the Average order value (AOV)

# %%
orders["order_total"].mean()
# Out:
# np.float64(17964.8329625)

# %%
###Used a round function

orders["order_total"].mean().round(2)
# Out:
# np.float64(17964.83)

# %% [markdown]
# How many Unique Customers have placed orders?

# %%
customers=pd.read_csv('/customers.csv')
customers.head(5)
# Out:
#    customer_id first_name last_name                    email       phone  \
# 0            1        Sai    Sharma     ssharma251@yahoo.com  9117550026
# 1            2      Aarav  Kulkarni  akulkarni715@example.in  9319300868
# 2            3     Saanvi    Khanna     skhanna722@gmail.com  9022021263
# 3            4     Ishaan    Kapoor    ikapoor168@example.in  9396568720
# 4            5      Kiara      Nair     knair147@outlook.com  9175745391
#
#         city        state  pincode  created_at
# 0     Jaipur    Rajasthan   477442  2024-06-09
# 1       Pune  Maharashtra   859358  2023-09-26
# 2    Kolkata  West Bengal   636760  2023-10-13
# 3  Ahmedabad      Gujarat   640957  2022-08-06
# 4      Patna        Bihar   800167  2023-03-09

# %%
customers["customer_id"].nunique()
# Out:
# 350

# %%
###Analysing the customers full_name and last_name from the datasets
customers["full_name"]=customers["first_name"]+" "+customers["last_name"]
customers.head(5)
# Out:
#    customer_id first_name last_name                    email       phone  \
# 0            1        Sai    Sharma     ssharma251@yahoo.com  9117550026
# 1            2      Aarav  Kulkarni  akulkarni715@example.in  9319300868
# 2            3     Saanvi    Khanna     skhanna722@gmail.com  9022021263
# 3            4     Ishaan    Kapoor    ikapoor168@example.in  9396568720
# 4            5      Kiara      Nair     knair147@outlook.com  9175745391
#
#         city        state  pincode  created_at       full_name
# 0     Jaipur    Rajasthan   477442  2024-06-09      Sai Sharma
# 1       Pune  Maharashtra   859358  2023-09-26  Aarav Kulkarni
# 2    Kolkata  West Bengal   636760  2023-10-13   Saanvi Khanna
# 3  Ahmedabad      Gujarat   640957  2022-08-06   Ishaan Kapoor
# 4      Patna        Bihar   800167  2023-03-09      Kiara Nair

# %%
customers['full_name'].value_counts()
# Out:
# full_name
# Ayaan Chatterjee    3
# Saanvi Nair         3
# Tara Gupta          3
# Aarya Rastogi       3
# Sai Sharma          3
#                    ..
# Kabir Mehta         1
# Sai Mishra          1
# Meera Sharma        1
# Kartik Mehta        1
# Saanvi Chawla       1
# Name: count, Length: 299, dtype: int64

# %%
###Same customers who have created the same accounts in multi-time

name_counts = customers["full_name"].value_counts().reset_index(name='count')
name_analysis = name_counts[name_counts["count"] > 1]
name_analysis
# Out:
#            full_name  count
# 0   Ayaan Chatterjee      3
# 1        Saanvi Nair      3
# 2         Tara Gupta      3
# 3      Aarya Rastogi      3
# 4         Sai Sharma      3
# 5        Riya Khanna      3
# 6          Ira Mehta      3
# 7       Dhruv Pillai      2
# 8         Mira Gupta      2
# 9       Virat Khanna      2
# 10      Aisha Shetty      2
# 11    Ayaan Banerjee      2
# 12       Myra Mishra      2
# 13    Arjun Bhandari      2
# 14       Aarya Joshi      2
# 15     Ananya Pillai      2
# 16       Rudra Verma      2
# 17       Aisha Patel      2
# 18       Kabir Desai      2
# 19      Aarohi Joshi      2
# 20     Aarav Trivedi      2
# 21        Sai Kapoor      2
# 22    Sai Chatterjee      2
# 23       Pranav Khan      2
# 24       Kabir Patel      2
# 25        Myra Reddy      2
# 26     Arnav Goswami      2
# 27       Kavya Yadav      2
# 28     Tara Kulkarni      2
# 29    Anika Banerjee      2
# 30       Krish Gupta      2
# 31        Myra Joshi      2
# ...

# %%
customers["full_name"].nunique()
# Out:
# 299

# %%
###Analysis a  person with same name who is in the dataset

customers[customers["full_name"]=="Sai Sharma"]
# Out:
#      customer_id first_name last_name                 email       phone  \
# 0              1        Sai    Sharma  ssharma251@yahoo.com  9117550026
# 262          263        Sai    Sharma  ssharma641@gmail.com  9726403826
# 268          269        Sai    Sharma  ssharma574@gmail.com  9233172206
#
#        city      state  pincode  created_at   full_name
# 0    Jaipur  Rajasthan   477442  2024-06-09  Sai Sharma
# 262   Patna      Bihar   520357  2022-04-27  Sai Sharma
# 268   Kochi     Kerala   650090  2023-01-28  Sai Sharma
